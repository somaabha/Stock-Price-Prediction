# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings ("ignore")

# %%
#reading dataset
df=pd.read_csv("C:/Users/somaa/Downloads/NFLX.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2022-01-31  20047500
# 2022-02-01  22542300
# 2022-02-02  14346000
# 2022-02-03   9905200
# 2022-02-04   7782400

# %%
cls = df[['Close']]
cls.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1=cls.values
df1
# Out:
# array([[254.259995],
#        [265.720001],
#        [264.559998],
#        ...,
#        [429.480011],
#        [405.600006],
#        [410.170013]])

# %%
df1.shape
# Out:
# (1009, 1)

# %%
#plotting the data
plt.figure(figsize=(10, 5))
plt.plot(df1)

# %%
#scalling the data
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1
# Out:
# array([[0.04451626],
#        [0.06954849],
#        [0.06701469],
#        ...,
#        [0.4272515 ],
#        [0.37509011],
#        [0.38507243]])

# %%
len(df1)
# Out:
# 1009

# %%
#Defining test and train data sizes
train_size = int(len(df1)*0.80)
test_size = len(df1) - train_size

# %%
train_size,test_size
# Out:
# (807, 202)

# %%
#Splitting data between train and test
train, test = df1[0:train_size,:], df1[train_size:len(df1),:1]

# %%
len(train),len(test)
# Out:
# (807, 202)

# %%
#creating dataset matrix for LSTM model 

def create_df(dataset,step):
    X, y = [], []
    for i in range(len(dataset)-step-1):
        ds = dataset[i:(i+step), 0]
        X.append(ds)
        y.append(dataset[i + step, 0])
    return np.array(X), np.array(y)

# %%
#Taking 100 days price as one record for training
time_stamp = 100
X_train, y_train = create_df(train,time_stamp)
X_test, y_test = create_df(test,time_stamp)

# %%
X_train.shape,y_train.shape
# Out:
# ((706, 100), (706,))

# %%
X_test.shape, y_test.shape
# Out:
# ((101, 100), (101,))

# %%
#Reshaping data to fit into LSTM model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
#importing libraries for lstm model
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
#Creating LSTM model using keras
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(LSTM(units=50,return_sequences=True))
model.add(LSTM(units=50))
model.add(Dense(units=1,activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Training model with adam optimizer and mean squared error loss function
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=128)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 11s 756ms/step - loss: 0.0558 - val_loss: 0.0440
# Epoch 2/100
# 6/6 [==============================] - 3s 422ms/step - loss: 0.0136 - val_loss: 0.0872
# Epoch 3/100
# 6/6 [==============================] - 2s 411ms/step - loss: 0.0113 - val_loss: 0.0263
# Epoch 4/100
# 6/6 [==============================] - 3s 421ms/step - loss: 0.0064 - val_loss: 0.0171
# Epoch 5/100
# 6/6 [==============================] - 2s 418ms/step - loss: 0.0046 - val_loss: 0.0268
# Epoch 6/100
# 6/6 [==============================] - 3s 421ms/step - loss: 0.0039 - val_loss: 0.0158
# Epoch 7/100
# 6/6 [==============================] - 3s 431ms/step - loss: 0.0032 - val_loss: 0.0152
# Epoch 8/100
# 6/6 [==============================] - 3s 429ms/step - loss: 0.0030 - val_loss: 0.0150
# Epoch 9/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0030 - val_loss: 0.0160
# Epoch 10/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0029 - val_loss: 0.0143
# Epoch 11/100
# 6/6 [==============================] - 3s 418ms/step - loss: 0.0029 - val_loss: 0.0150
# Epoch 12/100
# 6/6 [==============================] - 3s 423ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 13/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0028 - val_loss: 0.0141
# Epoch 14/100
# 6/6 [==============================] - 3s 430ms/step - loss: 0.0027 - val_loss: 0.0135
# Epoch 15/100
# 6/6 [==============================] - 2s 411ms/step - loss: 0.0027 - val_loss: 0.0137
# Epoch 16/100
# 6/6 [==============================] - 3s 421ms/step - loss: 0.0027 - val_loss: 0.0131
# Epoch 17/100
# 6/6 [==============================] - 2s 407ms/step - loss: 0.0026 - val_loss: 0.0133
# Epoch 18/100
# 6/6 [==============================] - 2s 409ms/step - loss: 0.0026 - val_loss: 0.0125
# Epoch 19/100
# 6/6 [==============================] - 3s 425ms/step - loss: 0.0026 - val_loss: 0.0127
# Epoch 20/100
# 6/6 [==============================] - 2s 417ms/step - loss: 0.0025 - val_loss: 0.0118
# Epoch 21/100
# 6/6 [==============================] - 2s 407ms/step - loss: 0.0025 - val_loss: 0.0122
# Epoch 22/100
# 6/6 [==============================] - 2s 413ms/step - loss: 0.0025 - val_loss: 0.0115
# Epoch 23/100
# 6/6 [==============================] - 2s 401ms/step - loss: 0.0024 - val_loss: 0.0111
# Epoch 24/100
# 6/6 [==============================] - 3s 419ms/step - loss: 0.0024 - val_loss: 0.0110
# Epoch 25/100
# 6/6 [==============================] - 2s 417ms/step - loss: 0.0024 - val_loss: 0.0109
# Epoch 26/100
# 6/6 [==============================] - 3s 423ms/step - loss: 0.0023 - val_loss: 0.0101
# Epoch 27/100
# 6/6 [==============================] - 3s 423ms/step - loss: 0.0023 - val_loss: 0.0098
# Epoch 28/100
# 6/6 [==============================] - 3s 422ms/step - loss: 0.0023 - val_loss: 0.0095
# Epoch 29/100
# 6/6 [==============================] - 3s 415ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 30/100
# 6/6 [==============================] - 2s 413ms/step - loss: 0.0022 - val_loss: 0.0108
# Epoch 31/100
# 6/6 [==============================] - 3s 422ms/step - loss: 0.0022 - val_loss: 0.0089
# Epoch 32/100
# 6/6 [==============================] - 3s 433ms/step - loss: 0.0023 - val_loss: 0.0091
# Epoch 33/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 34/100
# 6/6 [==============================] - 2s 419ms/step - loss: 0.0021 - val_loss: 0.0089
# Epoch 35/100
# 6/6 [==============================] - 3s 421ms/step - loss: 0.0021 - val_loss: 0.0077
# Epoch 36/100
# 6/6 [==============================] - 3s 429ms/step - loss: 0.0022 - val_loss: 0.0076
# Epoch 37/100
# 6/6 [==============================] - 3s 423ms/step - loss: 0.0022 - val_loss: 0.0099
# Epoch 38/100
# 6/6 [==============================] - 3s 429ms/step - loss: 0.0022 - val_loss: 0.0076
# Epoch 39/100
# 6/6 [==============================] - 3s 428ms/step - loss: 0.0020 - val_loss: 0.0073
# Epoch 40/100
# 6/6 [==============================] - 2s 413ms/step - loss: 0.0020 - val_loss: 0.0078
# Epoch 41/100
# 6/6 [==============================] - 3s 424ms/step - loss: 0.0019 - val_loss: 0.0070
# Epoch 42/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0019 - val_loss: 0.0069
# Epoch 43/100
# 6/6 [==============================] - 3s 429ms/step - loss: 0.0019 - val_loss: 0.0068
# Epoch 44/100
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0019 - val_loss: 0.0070
# Epoch 45/100
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0019 - val_loss: 0.0070
# Epoch 46/100
# 6/6 [==============================] - 3s 416ms/step - loss: 0.0019 - val_loss: 0.0068
# Epoch 47/100
# 6/6 [==============================] - 3s 433ms/step - loss: 0.0018 - val_loss: 0.0066
# Epoch 48/100
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0018 - val_loss: 0.0066
# Epoch 49/100
# 6/6 [==============================] - 3s 431ms/step - loss: 0.0018 - val_loss: 0.0066
# Epoch 50/100
# 6/6 [==============================] - 3s 428ms/step - loss: 0.0018 - val_loss: 0.0063
# Epoch 51/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0017 - val_loss: 0.0065
# Epoch 52/100
# 6/6 [==============================] - 3s 419ms/step - loss: 0.0018 - val_loss: 0.0063
# Epoch 53/100
# 6/6 [==============================] - 3s 430ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 54/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0017 - val_loss: 0.0065
# Epoch 55/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0017 - val_loss: 0.0084
# Epoch 56/100
# 6/6 [==============================] - 3s 431ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 57/100
# 6/6 [==============================] - 3s 430ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 58/100
# 6/6 [==============================] - 3s 442ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 59/100
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 60/100
# 6/6 [==============================] - 3s 431ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 61/100
# 6/6 [==============================] - 2s 415ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 62/100
# 6/6 [==============================] - 3s 425ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 63/100
# 6/6 [==============================] - 3s 422ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 64/100
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 65/100
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0016 - val_loss: 0.0093
# Epoch 66/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0017 - val_loss: 0.0083
# Epoch 67/100
# 6/6 [==============================] - 3s 430ms/step - loss: 0.0018 - val_loss: 0.0068
# Epoch 68/100
# 6/6 [==============================] - 3s 429ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 69/100
# 6/6 [==============================] - 3s 416ms/step - loss: 0.0015 - val_loss: 0.0063
# Epoch 70/100
# 6/6 [==============================] - 3s 442ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 71/100
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 72/100
# 6/6 [==============================] - 3s 442ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 73/100
# 6/6 [==============================] - 3s 433ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 74/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 75/100
# 6/6 [==============================] - 3s 418ms/step - loss: 0.0014 - val_loss: 0.0068
# Epoch 76/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0015 - val_loss: 0.0069
# Epoch 77/100
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 78/100
# 6/6 [==============================] - 3s 449ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 79/100
# 6/6 [==============================] - 3s 441ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 80/100
# 6/6 [==============================] - 3s 423ms/step - loss: 0.0014 - val_loss: 0.0054
# Epoch 81/100
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 82/100
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 83/100
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 84/100
# 6/6 [==============================] - 3s 442ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 85/100
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0014 - val_loss: 0.0054
# Epoch 86/100
# 6/6 [==============================] - 3s 445ms/step - loss: 0.0012 - val_loss: 0.0051
# Epoch 87/100
# 6/6 [==============================] - 3s 443ms/step - loss: 0.0012 - val_loss: 0.0055
# Epoch 88/100
# 6/6 [==============================] - 3s 433ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 89/100
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 90/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 91/100
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0013 - val_loss: 0.0051
# Epoch 92/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 93/100
# 6/6 [==============================] - 3s 427ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 94/100
# 6/6 [==============================] - 3s 425ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 95/100
# 6/6 [==============================] - 3s 432ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 96/100
# 6/6 [==============================] - 3s 433ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 97/100
# 6/6 [==============================] - 2s 407ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 98/100
# 6/6 [==============================] - 3s 421ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 99/100
# 6/6 [==============================] - 3s 419ms/step - loss: 0.0011 - val_loss: 0.0050
# Epoch 100/100
# 6/6 [==============================] - 3s 426ms/step - loss: 0.0011 - val_loss: 0.0046

# %%
#PLotting loss, it shows that loss has decreased significantly and model trained well
loss = model.history.history['loss']
plt.plot(loss)

# %%
#Predicitng on train and test data
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 23/23 [==============================] - 3s 53ms/step
# 4/4 [==============================] - 0s 47ms/step

# %%
#Inverse transformation to get actual value
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
#Comparing using data visualization
plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(df1))
plt.plot(train_predict)
plt.plot(test_predict)

# %%
test = np.vstack((train_predict,test_predict))

# %%
#Combining the predited data to create uniform data visualization
plt.figure(figsize=(10, 5))
plt.plot(scaler.inverse_transform(df1))
plt.plot(test)

# %%
len(test)
# Out:
# 807

# %%
#Getting the last 100 days records
fut_inp = test[707:]
fut_inp = fut_inp.reshape(1,-1)
fut_inp.shape
# Out:
# (1, 100)

# %%
tmp_inp = list(fut_inp)

# %%
#Creating list of the last 100 data
tmp_inp = tmp_inp[0].tolist()

# %%
#Predicting next 30 days price suing the current data
#It will predict in sliding window manner (algorithm) with stride 1
lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(tmp_inp)>100):
        fut_inp = np.array(tmp_inp[1:])
        fut_inp=fut_inp.reshape(1,-1)
        fut_inp = fut_inp.reshape((1, n_steps, 1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        tmp_inp = tmp_inp[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        fut_inp = fut_inp.reshape((1, n_steps,1))
        yhat = model.predict(fut_inp, verbose=0)
        tmp_inp.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [[1.6672738790512085], [1.7325745820999146], [1.7688415050506592], [1.775750994682312], [1.764151930809021], [1.7343155145645142], [1.6796295642852783], [1.6050965785980225], [1.5252560377120972], [1.4514391422271729], [1.3887969255447388], [1.338036060333252], [1.2970503568649292], [1.2627811431884766], [1.2327181100845337], [1.2047524452209473], [1.1764816045761108], [1.1456069946289062], [1.1114715337753296], [1.0762300491333008], [1.044075846672058], [1.0191210508346558], [1.0037420988082886], [0.9982009530067444], [1.0011603832244873], [1.0104225873947144], [1.0235141515731812], [1.0380550622940063], [1.051975131034851], [1.0636417865753174]]

# %%
len(df1)
# Out:
# 1009

# %%
#Creating a dummy plane to plot graph one after another
plot_new=np.arange(1,101)
plot_pred=np.arange(101,131)

# %%
#plt.figure(figsize=(10, 5))
plt.plot(plot_new, scaler.inverse_transform(df1[909:]))
plt.plot(plot_pred, scaler.inverse_transform(lst_output))

# %%
ds_new = df1.tolist()

# %%
len(ds_new)
# Out:
# 1009

# %%
#filling the missing value with approx value
plt.figure(figsize=(10, 5))
ds_new.extend(lst_output)
plt.plot(ds_new[909:])

# %%
#Creating final data for plotting
final_graph = scaler.inverse_transform(ds_new).tolist()

# %%
#Plotting final results with predicted value after 30 Days
plt.figure(figsize=(10, 5))
plt.plot(final_graph,)
plt.ylabel("Price")
plt.xlabel("Time")
plt.title("Netflix prediction of next month close")
plt.axhline(y=final_graph[len(final_graph)-1], color = 'red', linestyle = ':', label = 'NEXT 30D: {0}'.format(round(float(*final_graph[len(final_graph)-1]),2)))
plt.legend()
